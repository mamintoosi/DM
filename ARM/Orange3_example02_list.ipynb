# %% [markdown]
# ## M. Amintoosi

# %%
from orangecontrib.associate.fpgrowth import *
dataset = [['Milk', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
           ['Dill', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
           ['Milk', 'Apple', 'Kidney Beans', 'Eggs'],
           ['Milk', 'Unicorn', 'Corn', 'Kidney Beans', 'Yogurt'],
           ['Corn', 'Onion', 'Kidney Beans', 'Ice cream', 'Eggs', 'Yogurt']]
from mlxtend.preprocessing import OnehotTransactions
oht = OnehotTransactions()
oht_ary = oht.fit(dataset).transform(dataset)
itemsets = dict(frequent_itemsets(oht_ary, .1))
rules = association_rules(itemsets, .6)
list(rules_stats(rules, itemsets, 10))
# Out:
# d:\ProgramData\Anaconda3\envs\tf_gpu\lib\site-packages\mlxtend\preprocessing\onehot.py:66: DeprecationWarning: OnehotTransactions has been deprecated and will be removed in future. Please use TransactionEncoder instead.
#   warnings.warn(msg, DeprecationWarning)
# [(frozenset({3, 4, 5, 8, 10}), frozenset({1}), 1, 1.0, 0.1, 2.0, 5.0, 0.08),
#  (frozenset({1, 4, 5, 8, 10}), frozenset({3}), 1, 1.0, 0.1, 4.0, 2.5, 0.06),
#  (frozenset({4, 5, 8, 10}), frozenset({1, 3}), 1, 1.0, 0.1, 1.0, 10.0, 0.09),
#  (frozenset({1, 3, 5, 8, 10}), frozenset({4}), 1, 1.0, 0.1, 1.0, 10.0, 0.09),
#  (frozenset({1, 5, 8, 10}), frozenset({3, 4}), 1, 1.0, 0.1, 1.0, 10.0, 0.09),
#  (frozenset({1, 3, 4, 8, 10}), frozenset({5}), 1, 1.0, 0.1, 5.0, 2.0, 0.05),
#  (frozenset({3, 4, 8, 10}), frozenset({1, 5}), 1, 1.0, 0.1, 2.0, 5.0, 0.08),
#  (frozenset({1, 4, 8, 10}), frozenset({3, 5}), 1, 1.0, 0.1, 4.0, 2.5, 0.06),
#  (frozenset({4, 8, 10}), frozenset({1, 3, 5}), 1, 1.0, 0.1, 1.0, 10.0, 0.09),
# ...

# %%
oht_ary

# %%
# بلد نیستم از تابع وان‌هات خودش استفاده کنم
# X, mapping = OneHot.encode(dataset, include_class=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-34543985a91f> in <module>
# ----> 1 X, mapping = OneHot.encode(dataset, include_class=True)
#
# d:\ProgramData\Anaconda3\envs\tf_gpu\lib\site-packages\orangecontrib\associate\fpgrowth.py in encode(table, include_class)
#     617         per row (LIL rows) is returned instead of the one-hot ndarray.
#     618         """
# --> 619         X, encoded, mapping = table.X, [], {}
#     620         if issparse(X):
#     621             encoded = X.tolil().rows.tolist()
#
# AttributeError: 'list' object has no attribute 'X'
