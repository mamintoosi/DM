# %% [markdown]
# # M.Amintoosi

# %%
import numpy as np
from orangecontrib.associate.fpgrowth import *

N = 30
X = np.random.random((N, 50)) > .9
itemsets = dict(frequent_itemsets(X, .1))
rules = association_rules(itemsets, .3)
list(rules_stats(rules, itemsets, N))
# Out:
# [(frozenset({2, 14, 40}),
#   frozenset({16}),
#   3,
#   1.0,
#   0.1,
#   1.3333333333333333,
#   7.5,
#   0.08666666666666667),
#  (frozenset({14, 40}), frozenset({2, 16}), 3, 1.0, 0.1, 1.0, 10.0, 0.09),
#  (frozenset({2, 40}), frozenset({14, 16}), 3, 1.0, 0.1, 1.0, 10.0, 0.09),
#  (frozenset({40}), frozenset({2, 14, 16}), 3, 0.5, 0.2, 0.5, 5.0, 0.08),
#  (frozenset({2, 14, 16}), frozenset({40}), 3, 1.0, 0.1, 2.0, 5.0, 0.08),
#  (frozenset({2, 14}), frozenset({16, 40}), 3, 1.0, 0.1, 1.0, 10.0, 0.09),
#  (frozenset({14}),
#   frozenset({2, 16, 40}),
#   3,
#   0.75,
#   0.13333333333333333,
#   0.75,
#   7.5,
#   0.08666666666666667),
#  (frozenset({2}),
#   frozenset({14, 16, 40}),
#   3,
#   0.75,
#   0.13333333333333333,
#   0.75,
#   7.5,
#   0.08666666666666667),
#  (frozenset({14, 16}), frozenset({2, 40}), 3, 1.0, 0.1, 1.0, 10.0, 0.09),
#  (frozenset({2, 16}), frozenset({14, 40}), 3, 1.0, 0.1, 1.0, 10.0, 0.09),
#  (frozenset({16}),
#   frozenset({2, 14, 40}),
#   3,
#   0.75,
#   0.13333333333333333,
#   0.75,
#   7.5,
#   0.08666666666666667),
#  (frozenset({14, 16, 40}),
#   frozenset({2}),
#   3,
#   1.0,
#   0.1,
#   1.3333333333333333,
#   7.5,
#   0.08666666666666667),
#  (frozenset({2, 16, 40}),
#   frozenset({14}),
#   3,
#   1.0,
#   0.1,
#   1.3333333333333333,
#   7.5,
#   0.08666666666666667),
#  (frozenset({16, 40}), frozenset({2, 14}), 3, 1.0, 0.1, 1.0, 10.0, 0.09),
#  (frozenset({2, 14}), frozenset({40}), 3, 1.0, 0.1, 2.0, 5.0, 0.08),
#  (frozenset({14}),
#   frozenset({2, 40}),
#   3,
#   0.75,
#   0.13333333333333333,
#   0.75,
#   7.5,
#   0.08666666666666667),
#  (frozenset({2}),
#   frozenset({14, 40}),
#   3,
#   0.75,
#   0.13333333333333333,
#   0.75,
#   7.5,
#   0.08666666666666667),
#  (frozenset({14, 40}),
#   frozenset({2}),
#   3,
#   1.0,
#   0.1,
#   1.3333333333333333,
#   7.5,
#   0.08666666666666667),
#  (frozenset({2, 40}),
#   frozenset({14}),
#   3,
#   1.0,
#   0.1,
#   1.3333333333333333,
#   7.5,
#   0.08666666666666667),
#  (frozenset({40}), frozenset({2, 14}), 3, 0.5, 0.2, 0.5, 5.0, 0.08),
#  (frozenset({2, 14}),
#   frozenset({16}),
#   3,
#   1.0,
#   0.1,
#   1.3333333333333333,
#   7.5,
#   0.08666666666666667),
#  (frozenset({14}),
#   frozenset({2, 16}),
#   3,
#   0.75,
#   0.13333333333333333,
#   0.75,
#   7.5,
#   0.08666666666666667),
#  (frozenset({2}),
#   frozenset({14, 16}),
#   3,
#   0.75,
#   0.13333333333333333,
#   0.75,
#   7.5,
#   0.08666666666666667),
#  (frozenset({14, 16}),
#   frozenset({2}),
#   3,
#   1.0,
#   0.1,
#   1.3333333333333333,
#   7.5,
#   0.08666666666666667),
#  (frozenset({2, 16}),
#   frozenset({14}),
#   3,
#   1.0,
#   0.1,
#   1.3333333333333333,
#   7.5,
#   0.08666666666666667),
#  (frozenset({16}),
#   frozenset({2, 14}),
#   3,
#   0.75,
#   0.13333333333333333,
#   0.75,
#   7.5,
#   0.08666666666666667),
#  (frozenset({2, 40}),
#   frozenset({16}),
#   3,
#   1.0,
#   0.1,
#   1.3333333333333333,
#   7.5,
#   0.08666666666666667),
#  (frozenset({40}), frozenset({2, 16}), 3, 0.5, 0.2, 0.5, 5.0, 0.08),
#  (frozenset({2, 16}), frozenset({40}), 3, 1.0, 0.1, 2.0, 5.0, 0.08),
#  (frozenset({2}),
#   frozenset({16, 40}),
#   3,
#   0.75,
#   0.13333333333333333,
#   0.75,
#   7.5,
#   0.08666666666666667),
#  (frozenset({16}),
#   frozenset({2, 40}),
#   3,
#   0.75,
#   0.13333333333333333,
#   0.75,
#   7.5,
#   0.08666666666666667),
#  (frozenset({16, 40}),
#   frozenset({2}),
#   3,
#   1.0,
#   0.1,
#   1.3333333333333333,
#   7.5,
#   0.08666666666666667),
#  (frozenset({14, 40}),
#   frozenset({16}),
#   3,
#   1.0,
#   0.1,
#   1.3333333333333333,
#   7.5,
#   0.08666666666666667),
#  (frozenset({40}), frozenset({14, 16}), 3, 0.5, 0.2, 0.5, 5.0, 0.08),
#  (frozenset({14, 16}), frozenset({40}), 3, 1.0, 0.1, 2.0, 5.0, 0.08),
#  (frozenset({14}),
#   frozenset({16, 40}),
#   3,
#   0.75,
#   0.13333333333333333,
#   0.75,
#   7.5,
#   0.08666666666666667),
#  (frozenset({16}),
#   frozenset({14, 40}),
#   3,
#   0.75,
#   0.13333333333333333,
#   0.75,
#   7.5,
#   0.08666666666666667),
#  (frozenset({16, 40}),
#   frozenset({14}),
#   3,
#   1.0,
#   0.1,
#   1.3333333333333333,
#   7.5,
#   0.08666666666666667),
#  (frozenset({21}),
#   frozenset({42}),
#   3,
#   0.42857142857142855,
#   0.23333333333333334,
#   1.0,
#   1.8367346938775508,
#   0.04555555555555556),
#  (frozenset({42}),
#   frozenset({21}),
#   3,
#   0.42857142857142855,
#   0.23333333333333334,
#   1.0,
#   1.8367346938775508,
#   0.04555555555555556),
#  (frozenset({21}),
#   frozenset({40}),
#   3,
#   0.42857142857142855,
#   0.23333333333333334,
#   0.8571428571428571,
#   2.142857142857143,
#   0.05333333333333334),
#  (frozenset({40}),
#   frozenset({21}),
#   3,
#   0.5,
#   0.2,
#   1.1666666666666667,
#   2.142857142857143,
#   0.05333333333333334),
#  (frozenset({46}),
#   frozenset({24}),
#   3,
#   0.5,
#   0.2,
#   1.3333333333333333,
#   1.875,
#   0.04666666666666667),
#  (frozenset({24}),
#   frozenset({46}),
#   3,
#   0.375,
#   0.26666666666666666,
#   0.75,
#   1.875,
#   0.04666666666666667),
#  (frozenset({46}),
#   frozenset({17}),
#   3,
#   0.5,
#   0.2,
#   0.8333333333333334,
#   3.0,
#   0.06666666666666667),
#  (frozenset({17}),
#   frozenset({46}),
#   3,
#   0.6,
#   0.16666666666666666,
#   1.2,
#   3.0,
#   0.06666666666666667),
#  (frozenset({2}),
#   frozenset({40}),
#   3,
#   0.75,
#   0.13333333333333333,
#   1.5,
#   3.75,
#   0.07333333333333333),
#  (frozenset({40}),
#   frozenset({2}),
#   3,
#   0.5,
#   0.2,
#   0.6666666666666666,
#   3.75,
#   0.07333333333333333),
#  (frozenset({14}),
#   frozenset({2}),
#   3,
#   0.75,
#   0.13333333333333333,
#   1.0,
#   5.625,
#   0.08222222222222222),
#  (frozenset({2}),
#   frozenset({14}),
#   3,
#   0.75,
#   0.13333333333333333,
#   1.0,
#   5.625,
#   0.08222222222222222),
#  (frozenset({14}),
#   frozenset({40}),
#   3,
#   0.75,
#   0.13333333333333333,
#   1.5,
#   3.75,
#   0.07333333333333333),
#  (frozenset({40}),
#   frozenset({14}),
#   3,
#   0.5,
#   0.2,
#   0.6666666666666666,
#   3.75,
#   0.07333333333333333),
#  (frozenset({2}),
#   frozenset({16}),
#   3,
#   0.75,
#   0.13333333333333333,
#   1.0,
#   5.625,
#   0.08222222222222222),
#  (frozenset({16}),
#   frozenset({2}),
#   3,
#   0.75,
#   0.13333333333333333,
#   1.0,
#   5.625,
#   0.08222222222222222),
#  (frozenset({14}),
#   frozenset({16}),
#   3,
#   0.75,
#   0.13333333333333333,
#   1.0,
#   5.625,
#   0.08222222222222222),
#  (frozenset({16}),
#   frozenset({14}),
#   3,
#   0.75,
#   0.13333333333333333,
#   1.0,
#   5.625,
#   0.08222222222222222),
#  (frozenset({40}),
#   frozenset({16}),
#   3,
#   0.5,
#   0.2,
#   0.6666666666666666,
#   3.75,
#   0.07333333333333333),
#  (frozenset({16}),
#   frozenset({40}),
#   3,
#   0.75,
#   0.13333333333333333,
#   1.5,
#   3.75,
#   0.07333333333333333)]
