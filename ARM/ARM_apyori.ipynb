# %% [markdown]
# ## M. Amintoosi
# ## کاوش الگوهای پرتکرار
# استخراج قوانین انجمنی
#
# https://pypi.org/project/apyori/
#
# http://www.zaxrosenberg.com/unofficial-apyori-documentation/

# %%
import numpy as np  
import matplotlib.pyplot as plt  
import pandas as pd  
from apyori import apriori

# %%
dataset = [['Milk', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
           ['Dill', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
           ['Milk', 'Apple', 'Kidney Beans', 'Eggs'],
           ['Milk', 'Unicorn', 'Corn', 'Kidney Beans', 'Yogurt'],
           ['Corn', 'Onion', 'Kidney Beans', 'Ice cream', 'Eggs', 'Yogurt']]

association_rules = apriori(dataset)#, min_support=0.1, min_confidence=0.4, min_lift=1.2, min_length=2)  
association_results = list(association_rules) 
print(len(association_results))
# Out:
# 171

# %%
minNumX = 2 # antecedent (items_base) and 
minNumY = 1 # consequent (items_add)
# قوانین با تعداد بیشتر از یک قلم در تالی تولید نمی‌شوند!
for item in association_results:
    # تکرار به تعداد قوانین موجود در آیتم
    for i in range(len(item[2])):
        if len(item[2][i][0]) < minNumX:
            continue
        if len(item[2][i][1]) < minNumY:
            continue
        set_items=[item[2][i][0]]
        Xitems = str([list(x) for x in set_items])
        set_items=[item[2][i][1]]
        Yitems = str([list(x) for x in set_items])
        print("Rule: " + Xitems + " -> " + Yitems)

        #second index of the inner list
        print("Support: " + str(item[1]))

        #third index of the list located at 0th
        #of the third index of the inner list

        print("Confidence: " + str(item[2][i][2]))
        print("Lift: " + str(item[2][i][3]))
        print("================")
    print("=====================================")
# Out:
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# Rule: [['Eggs', 'Apple']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Apple']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Kidney Beans']] -> [['Apple']]
# Support: 0.2
# Confidence: 0.25
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs', 'Apple']] -> [['Milk']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Milk', 'Apple']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Milk']] -> [['Apple']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# =====================================
# Rule: [['Kidney Beans', 'Apple']] -> [['Milk']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Milk', 'Apple']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Milk', 'Kidney Beans']] -> [['Apple']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# =====================================
# Rule: [['Eggs', 'Corn']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# ================
# Rule: [['Ice cream', 'Corn']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Ice cream']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Eggs', 'Corn']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Corn']] -> [['Eggs']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.625
# ================
# Rule: [['Eggs', 'Kidney Beans']] -> [['Corn']]
# Support: 0.2
# Confidence: 0.25
# Lift: 0.625
# ================
# =====================================
# Rule: [['Eggs', 'Corn']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Onion', 'Corn']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Onion']] -> [['Corn']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.8333333333333334
# ================
# =====================================
# Rule: [['Eggs', 'Corn']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Corn', 'Yogurt']] -> [['Eggs']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.625
# ================
# Rule: [['Eggs', 'Yogurt']] -> [['Corn']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.8333333333333334
# ================
# =====================================
# Rule: [['Ice cream', 'Corn']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Corn']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# Rule: [['Ice cream', 'Kidney Beans']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Ice cream', 'Corn']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Onion', 'Corn']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# ================
# Rule: [['Ice cream', 'Onion']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Ice cream', 'Corn']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Corn', 'Yogurt']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# Rule: [['Ice cream', 'Yogurt']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Kidney Beans', 'Corn']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Milk', 'Corn']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Milk', 'Kidney Beans']] -> [['Corn']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.8333333333333334
# ================
# =====================================
# Rule: [['Kidney Beans', 'Corn']] -> [['Onion']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Onion', 'Corn']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Onion']] -> [['Corn']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.8333333333333334
# ================
# =====================================
# Rule: [['Kidney Beans', 'Corn']] -> [['Unicorn']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# Rule: [['Unicorn', 'Corn']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Unicorn', 'Kidney Beans']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Kidney Beans', 'Corn']] -> [['Yogurt']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Corn', 'Yogurt']] -> [['Kidney Beans']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Yogurt']] -> [['Corn']]
# Support: 0.4
# Confidence: 0.5
# Lift: 1.25
# ================
# =====================================
# Rule: [['Milk', 'Corn']] -> [['Unicorn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# ================
# Rule: [['Unicorn', 'Corn']] -> [['Milk']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Milk', 'Unicorn']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Milk', 'Corn']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Corn', 'Yogurt']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Milk', 'Yogurt']] -> [['Corn']]
# Support: 0.2
# Confidence: 0.5
# Lift: 1.25
# ================
# =====================================
# Rule: [['Onion', 'Corn']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Corn', 'Yogurt']] -> [['Onion']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Onion', 'Yogurt']] -> [['Corn']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.8333333333333334
# ================
# =====================================
# Rule: [['Unicorn', 'Corn']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Corn', 'Yogurt']] -> [['Unicorn']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# Rule: [['Unicorn', 'Yogurt']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Eggs', 'Dill']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Dill']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Kidney Beans']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.25
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs', 'Dill']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Dill', 'Nutmeg']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Nutmeg']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# =====================================
# Rule: [['Eggs', 'Dill']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Onion', 'Dill']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Onion']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# =====================================
# Rule: [['Eggs', 'Dill']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Dill', 'Yogurt']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Yogurt']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# =====================================
# Rule: [['Kidney Beans', 'Dill']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Dill', 'Nutmeg']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Nutmeg']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# =====================================
# Rule: [['Kidney Beans', 'Dill']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Onion', 'Dill']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Onion']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# =====================================
# Rule: [['Kidney Beans', 'Dill']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Dill', 'Yogurt']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Yogurt']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.25
# Lift: 1.25
# ================
# =====================================
# Rule: [['Dill', 'Nutmeg']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Onion', 'Dill']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Onion', 'Nutmeg']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# =====================================
# Rule: [['Dill', 'Nutmeg']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Dill', 'Yogurt']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Yogurt', 'Nutmeg']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# =====================================
# Rule: [['Onion', 'Dill']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Dill', 'Yogurt']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Onion', 'Yogurt']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# =====================================
# Rule: [['Eggs', 'Ice cream']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Eggs', 'Kidney Beans']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 0.25
# Lift: 1.25
# ================
# Rule: [['Ice cream', 'Kidney Beans']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs', 'Ice cream']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Onion']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# Rule: [['Ice cream', 'Onion']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs', 'Ice cream']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Yogurt']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# Rule: [['Ice cream', 'Yogurt']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans']] -> [['Milk']]
# Support: 0.4
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Eggs', 'Milk']] -> [['Kidney Beans']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Milk', 'Kidney Beans']] -> [['Eggs']]
# Support: 0.4
# Confidence: 0.6666666666666667
# Lift: 0.8333333333333334
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans']] -> [['Nutmeg']]
# Support: 0.4
# Confidence: 0.5
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Nutmeg']] -> [['Kidney Beans']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Nutmeg']] -> [['Eggs']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans']] -> [['Onion']]
# Support: 0.6
# Confidence: 0.7499999999999999
# Lift: 1.2499999999999998
# ================
# Rule: [['Eggs', 'Onion']] -> [['Kidney Beans']]
# Support: 0.6
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Onion']] -> [['Eggs']]
# Support: 0.6
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans']] -> [['Yogurt']]
# Support: 0.6
# Confidence: 0.7499999999999999
# Lift: 0.9374999999999998
# ================
# Rule: [['Eggs', 'Yogurt']] -> [['Kidney Beans']]
# Support: 0.6
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Yogurt']] -> [['Eggs']]
# Support: 0.6
# Confidence: 0.7499999999999999
# Lift: 0.9374999999999998
# ================
# =====================================
# Rule: [['Eggs', 'Milk']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 0.5
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Nutmeg']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Milk', 'Nutmeg']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs', 'Milk']] -> [['Onion']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Eggs', 'Onion']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.5555555555555557
# ================
# Rule: [['Milk', 'Onion']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs', 'Milk']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.625
# ================
# Rule: [['Eggs', 'Yogurt']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.5555555555555557
# ================
# Rule: [['Milk', 'Yogurt']] -> [['Eggs']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.625
# ================
# =====================================
# Rule: [['Eggs', 'Nutmeg']] -> [['Onion']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Onion']] -> [['Nutmeg']]
# Support: 0.4
# Confidence: 0.6666666666666667
# Lift: 1.6666666666666667
# ================
# Rule: [['Onion', 'Nutmeg']] -> [['Eggs']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs', 'Nutmeg']] -> [['Yogurt']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Yogurt']] -> [['Nutmeg']]
# Support: 0.4
# Confidence: 0.6666666666666667
# Lift: 1.6666666666666667
# ================
# Rule: [['Yogurt', 'Nutmeg']] -> [['Eggs']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs', 'Onion']] -> [['Yogurt']]
# Support: 0.6
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Yogurt']] -> [['Onion']]
# Support: 0.6
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Onion', 'Yogurt']] -> [['Eggs']]
# Support: 0.6
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Ice cream', 'Kidney Beans']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Ice cream', 'Onion']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Onion']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# =====================================
# Rule: [['Ice cream', 'Kidney Beans']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Ice cream', 'Yogurt']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Yogurt']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 0.25
# Lift: 1.25
# ================
# =====================================
# Rule: [['Ice cream', 'Onion']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Ice cream', 'Yogurt']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Onion', 'Yogurt']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# =====================================
# Rule: [['Milk', 'Kidney Beans']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.8333333333333334
# ================
# Rule: [['Kidney Beans', 'Nutmeg']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Milk', 'Nutmeg']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# =====================================
# Rule: [['Milk', 'Kidney Beans']] -> [['Onion']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.5555555555555557
# ================
# Rule: [['Kidney Beans', 'Onion']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.5555555555555557
# ================
# Rule: [['Milk', 'Onion']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# =====================================
# Rule: [['Milk', 'Kidney Beans']] -> [['Unicorn']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# Rule: [['Unicorn', 'Kidney Beans']] -> [['Milk']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Milk', 'Unicorn']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# =====================================
# Rule: [['Milk', 'Kidney Beans']] -> [['Yogurt']]
# Support: 0.4
# Confidence: 0.6666666666666667
# Lift: 0.8333333333333334
# ================
# Rule: [['Kidney Beans', 'Yogurt']] -> [['Milk']]
# Support: 0.4
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Milk', 'Yogurt']] -> [['Kidney Beans']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.0
# ================
# =====================================
# Rule: [['Kidney Beans', 'Nutmeg']] -> [['Onion']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Kidney Beans', 'Onion']] -> [['Nutmeg']]
# Support: 0.4
# Confidence: 0.6666666666666667
# Lift: 1.6666666666666667
# ================
# Rule: [['Onion', 'Nutmeg']] -> [['Kidney Beans']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.0
# ================
# =====================================
# Rule: [['Kidney Beans', 'Nutmeg']] -> [['Yogurt']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Kidney Beans', 'Yogurt']] -> [['Nutmeg']]
# Support: 0.4
# Confidence: 0.5
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Nutmeg']] -> [['Kidney Beans']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.0
# ================
# =====================================
# Rule: [['Kidney Beans', 'Onion']] -> [['Yogurt']]
# Support: 0.6
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Kidney Beans', 'Yogurt']] -> [['Onion']]
# Support: 0.6
# Confidence: 0.7499999999999999
# Lift: 1.2499999999999998
# ================
# Rule: [['Onion', 'Yogurt']] -> [['Kidney Beans']]
# Support: 0.6
# Confidence: 1.0
# Lift: 1.0
# ================
# =====================================
# Rule: [['Unicorn', 'Kidney Beans']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Kidney Beans', 'Yogurt']] -> [['Unicorn']]
# Support: 0.2
# Confidence: 0.25
# Lift: 1.25
# ================
# Rule: [['Unicorn', 'Yogurt']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# =====================================
# Rule: [['Milk', 'Nutmeg']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Milk', 'Onion']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Onion', 'Nutmeg']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# =====================================
# Rule: [['Milk', 'Nutmeg']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Milk', 'Yogurt']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 0.5
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Nutmeg']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# =====================================
# Rule: [['Milk', 'Onion']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Milk', 'Yogurt']] -> [['Onion']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Onion', 'Yogurt']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.5555555555555557
# ================
# =====================================
# Rule: [['Milk', 'Unicorn']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Milk', 'Yogurt']] -> [['Unicorn']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# Rule: [['Unicorn', 'Yogurt']] -> [['Milk']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# =====================================
# Rule: [['Onion', 'Nutmeg']] -> [['Yogurt']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Nutmeg']] -> [['Onion']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Onion', 'Yogurt']] -> [['Nutmeg']]
# Support: 0.4
# Confidence: 0.6666666666666667
# Lift: 1.6666666666666667
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans', 'Apple']] -> [['Milk']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Milk', 'Apple']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Milk', 'Kidney Beans', 'Apple']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Milk']] -> [['Apple']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# =====================================
# Rule: [['Eggs', 'Ice cream', 'Corn']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Corn']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# ================
# Rule: [['Ice cream', 'Kidney Beans', 'Corn']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Ice cream']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Eggs', 'Ice cream', 'Corn']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Onion', 'Corn']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# ================
# Rule: [['Ice cream', 'Onion', 'Corn']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Onion', 'Ice cream']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Eggs', 'Ice cream', 'Corn']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Corn', 'Yogurt']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# ================
# Rule: [['Ice cream', 'Corn', 'Yogurt']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Ice cream', 'Yogurt']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans', 'Corn']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Onion', 'Corn']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Onion', 'Corn']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Onion']] -> [['Corn']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.8333333333333334
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans', 'Corn']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Corn', 'Yogurt']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Corn', 'Yogurt']] -> [['Eggs']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.625
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Yogurt']] -> [['Corn']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.8333333333333334
# ================
# =====================================
# Rule: [['Eggs', 'Onion', 'Corn']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Corn', 'Yogurt']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Onion', 'Corn', 'Yogurt']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Onion', 'Yogurt']] -> [['Corn']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.8333333333333334
# ================
# =====================================
# Rule: [['Ice cream', 'Kidney Beans', 'Corn']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Ice cream', 'Onion', 'Corn']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Onion', 'Corn']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# ================
# Rule: [['Ice cream', 'Kidney Beans', 'Onion']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Ice cream', 'Kidney Beans', 'Corn']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Ice cream', 'Corn', 'Yogurt']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Corn', 'Yogurt']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# Rule: [['Ice cream', 'Kidney Beans', 'Yogurt']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Ice cream', 'Onion', 'Corn']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Ice cream', 'Corn', 'Yogurt']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Onion', 'Corn', 'Yogurt']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# ================
# Rule: [['Ice cream', 'Onion', 'Yogurt']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Milk', 'Kidney Beans', 'Corn']] -> [['Unicorn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# ================
# Rule: [['Unicorn', 'Kidney Beans', 'Corn']] -> [['Milk']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Milk', 'Unicorn', 'Corn']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Milk', 'Unicorn', 'Kidney Beans']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Milk', 'Kidney Beans', 'Corn']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Kidney Beans', 'Corn', 'Yogurt']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Milk', 'Corn', 'Yogurt']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Milk', 'Kidney Beans', 'Yogurt']] -> [['Corn']]
# Support: 0.2
# Confidence: 0.5
# Lift: 1.25
# ================
# =====================================
# Rule: [['Kidney Beans', 'Onion', 'Corn']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Kidney Beans', 'Corn', 'Yogurt']] -> [['Onion']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Onion', 'Corn', 'Yogurt']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Onion', 'Yogurt']] -> [['Corn']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.8333333333333334
# ================
# =====================================
# Rule: [['Unicorn', 'Kidney Beans', 'Corn']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Kidney Beans', 'Corn', 'Yogurt']] -> [['Unicorn']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# Rule: [['Unicorn', 'Corn', 'Yogurt']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Unicorn', 'Kidney Beans', 'Yogurt']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Milk', 'Unicorn', 'Corn']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Milk', 'Corn', 'Yogurt']] -> [['Unicorn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# ================
# Rule: [['Unicorn', 'Corn', 'Yogurt']] -> [['Milk']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Milk', 'Unicorn', 'Yogurt']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans', 'Dill']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Eggs', 'Dill', 'Nutmeg']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Dill', 'Nutmeg']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Nutmeg']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans', 'Dill']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Onion', 'Dill']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Onion', 'Dill']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Onion']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans', 'Dill']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Dill', 'Yogurt']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Dill', 'Yogurt']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Yogurt']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# =====================================
# Rule: [['Eggs', 'Dill', 'Nutmeg']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Onion', 'Dill']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Onion', 'Dill', 'Nutmeg']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Onion', 'Nutmeg']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# =====================================
# Rule: [['Eggs', 'Dill', 'Nutmeg']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Dill', 'Yogurt']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Yogurt', 'Dill', 'Nutmeg']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Yogurt', 'Nutmeg']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# =====================================
# Rule: [['Eggs', 'Onion', 'Dill']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Dill', 'Yogurt']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Onion', 'Dill', 'Yogurt']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Onion', 'Yogurt']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# =====================================
# Rule: [['Kidney Beans', 'Dill', 'Nutmeg']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Kidney Beans', 'Onion', 'Dill']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Onion', 'Dill', 'Nutmeg']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Onion', 'Nutmeg']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# =====================================
# Rule: [['Kidney Beans', 'Dill', 'Nutmeg']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Kidney Beans', 'Dill', 'Yogurt']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Yogurt', 'Dill', 'Nutmeg']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Yogurt', 'Kidney Beans', 'Nutmeg']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# =====================================
# Rule: [['Kidney Beans', 'Onion', 'Dill']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Kidney Beans', 'Dill', 'Yogurt']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Onion', 'Dill', 'Yogurt']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Onion', 'Yogurt']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# =====================================
# Rule: [['Onion', 'Dill', 'Nutmeg']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Dill', 'Nutmeg']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Onion', 'Dill', 'Yogurt']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Yogurt', 'Onion', 'Nutmeg']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans', 'Ice cream']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Onion', 'Ice cream']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Onion']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# Rule: [['Ice cream', 'Kidney Beans', 'Onion']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans', 'Ice cream']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Ice cream', 'Yogurt']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Yogurt']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# Rule: [['Ice cream', 'Kidney Beans', 'Yogurt']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs', 'Onion', 'Ice cream']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Ice cream', 'Yogurt']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Onion', 'Yogurt']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# Rule: [['Ice cream', 'Onion', 'Yogurt']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans', 'Milk']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 0.5
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Nutmeg']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Eggs', 'Milk', 'Nutmeg']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Milk', 'Kidney Beans', 'Nutmeg']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans', 'Milk']] -> [['Onion']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Onion']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.5555555555555557
# ================
# Rule: [['Eggs', 'Milk', 'Onion']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Milk', 'Kidney Beans', 'Onion']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans', 'Milk']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.625
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Yogurt']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.5555555555555557
# ================
# Rule: [['Eggs', 'Milk', 'Yogurt']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Milk', 'Kidney Beans', 'Yogurt']] -> [['Eggs']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.625
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans', 'Nutmeg']] -> [['Onion']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Onion']] -> [['Nutmeg']]
# Support: 0.4
# Confidence: 0.6666666666666667
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Onion', 'Nutmeg']] -> [['Kidney Beans']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Onion', 'Nutmeg']] -> [['Eggs']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans', 'Nutmeg']] -> [['Yogurt']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Yogurt']] -> [['Nutmeg']]
# Support: 0.4
# Confidence: 0.6666666666666667
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Yogurt', 'Nutmeg']] -> [['Kidney Beans']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Yogurt', 'Kidney Beans', 'Nutmeg']] -> [['Eggs']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans', 'Onion']] -> [['Yogurt']]
# Support: 0.6
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Yogurt']] -> [['Onion']]
# Support: 0.6
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Onion', 'Yogurt']] -> [['Kidney Beans']]
# Support: 0.6
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Onion', 'Yogurt']] -> [['Eggs']]
# Support: 0.6
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs', 'Milk', 'Nutmeg']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Milk', 'Onion']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Eggs', 'Onion', 'Nutmeg']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Milk', 'Onion', 'Nutmeg']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs', 'Milk', 'Nutmeg']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Milk', 'Yogurt']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Eggs', 'Yogurt', 'Nutmeg']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Milk', 'Yogurt', 'Nutmeg']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs', 'Milk', 'Onion']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Milk', 'Yogurt']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Onion', 'Yogurt']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.5555555555555557
# ================
# Rule: [['Milk', 'Onion', 'Yogurt']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs', 'Onion', 'Nutmeg']] -> [['Yogurt']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Yogurt', 'Nutmeg']] -> [['Onion']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Onion', 'Yogurt']] -> [['Nutmeg']]
# Support: 0.4
# Confidence: 0.6666666666666667
# Lift: 1.6666666666666667
# ================
# Rule: [['Yogurt', 'Onion', 'Nutmeg']] -> [['Eggs']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Ice cream', 'Kidney Beans', 'Onion']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Ice cream', 'Kidney Beans', 'Yogurt']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Ice cream', 'Onion', 'Yogurt']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Onion', 'Yogurt']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# =====================================
# Rule: [['Milk', 'Kidney Beans', 'Nutmeg']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Milk', 'Kidney Beans', 'Onion']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Kidney Beans', 'Onion', 'Nutmeg']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Milk', 'Onion', 'Nutmeg']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# =====================================
# Rule: [['Milk', 'Kidney Beans', 'Nutmeg']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Milk', 'Kidney Beans', 'Yogurt']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 0.5
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Kidney Beans', 'Nutmeg']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Milk', 'Yogurt', 'Nutmeg']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# =====================================
# Rule: [['Milk', 'Kidney Beans', 'Onion']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Milk', 'Kidney Beans', 'Yogurt']] -> [['Onion']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Kidney Beans', 'Onion', 'Yogurt']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.5555555555555557
# ================
# Rule: [['Milk', 'Onion', 'Yogurt']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# =====================================
# Rule: [['Milk', 'Unicorn', 'Kidney Beans']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Milk', 'Kidney Beans', 'Yogurt']] -> [['Unicorn']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# Rule: [['Unicorn', 'Kidney Beans', 'Yogurt']] -> [['Milk']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Milk', 'Unicorn', 'Yogurt']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# =====================================
# Rule: [['Kidney Beans', 'Onion', 'Nutmeg']] -> [['Yogurt']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Kidney Beans', 'Nutmeg']] -> [['Onion']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Kidney Beans', 'Onion', 'Yogurt']] -> [['Nutmeg']]
# Support: 0.4
# Confidence: 0.6666666666666667
# Lift: 1.6666666666666667
# ================
# Rule: [['Yogurt', 'Onion', 'Nutmeg']] -> [['Kidney Beans']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.0
# ================
# =====================================
# Rule: [['Milk', 'Onion', 'Nutmeg']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Milk', 'Yogurt', 'Nutmeg']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Milk', 'Onion', 'Yogurt']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Yogurt', 'Onion', 'Nutmeg']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans', 'Ice cream', 'Corn']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Onion', 'Ice cream', 'Corn']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Onion', 'Corn']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# ================
# Rule: [['Ice cream', 'Kidney Beans', 'Onion', 'Corn']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Onion', 'Ice cream']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans', 'Ice cream', 'Corn']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Ice cream', 'Corn', 'Yogurt']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Corn', 'Yogurt']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# ================
# Rule: [['Ice cream', 'Kidney Beans', 'Corn', 'Yogurt']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Ice cream', 'Yogurt']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Eggs', 'Onion', 'Ice cream', 'Corn']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Ice cream', 'Corn', 'Yogurt']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Onion', 'Corn', 'Yogurt']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# ================
# Rule: [['Ice cream', 'Onion', 'Corn', 'Yogurt']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Onion', 'Ice cream', 'Yogurt']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans', 'Onion', 'Corn']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Corn', 'Yogurt']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Onion', 'Corn', 'Yogurt']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Onion', 'Corn', 'Yogurt']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Onion', 'Yogurt']] -> [['Corn']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.8333333333333334
# ================
# =====================================
# Rule: [['Ice cream', 'Kidney Beans', 'Onion', 'Corn']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Ice cream', 'Kidney Beans', 'Corn', 'Yogurt']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Ice cream', 'Onion', 'Corn', 'Yogurt']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Onion', 'Corn', 'Yogurt']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# ================
# Rule: [['Ice cream', 'Kidney Beans', 'Onion', 'Yogurt']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Milk', 'Unicorn', 'Kidney Beans', 'Corn']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Milk', 'Kidney Beans', 'Corn', 'Yogurt']] -> [['Unicorn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# ================
# Rule: [['Unicorn', 'Kidney Beans', 'Corn', 'Yogurt']] -> [['Milk']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Milk', 'Unicorn', 'Corn', 'Yogurt']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Milk', 'Unicorn', 'Kidney Beans', 'Yogurt']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans', 'Dill', 'Nutmeg']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Onion', 'Dill']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Eggs', 'Onion', 'Dill', 'Nutmeg']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Onion', 'Dill', 'Nutmeg']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Onion', 'Nutmeg']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans', 'Dill', 'Nutmeg']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Dill', 'Yogurt']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Eggs', 'Yogurt', 'Dill', 'Nutmeg']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Yogurt', 'Kidney Beans', 'Dill', 'Nutmeg']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Yogurt', 'Kidney Beans', 'Nutmeg']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans', 'Onion', 'Dill']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Dill', 'Yogurt']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Onion', 'Dill', 'Yogurt']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Onion', 'Dill', 'Yogurt']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Onion', 'Yogurt']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# =====================================
# Rule: [['Eggs', 'Onion', 'Dill', 'Nutmeg']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Yogurt', 'Dill', 'Nutmeg']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Onion', 'Dill', 'Yogurt']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Yogurt', 'Onion', 'Dill', 'Nutmeg']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Yogurt', 'Onion', 'Nutmeg']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# =====================================
# Rule: [['Kidney Beans', 'Onion', 'Dill', 'Nutmeg']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Kidney Beans', 'Dill', 'Nutmeg']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Kidney Beans', 'Onion', 'Dill', 'Yogurt']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Yogurt', 'Onion', 'Dill', 'Nutmeg']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Yogurt', 'Kidney Beans', 'Onion', 'Nutmeg']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans', 'Onion', 'Ice cream']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Ice cream', 'Yogurt']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Onion', 'Ice cream', 'Yogurt']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Onion', 'Yogurt']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# Rule: [['Ice cream', 'Kidney Beans', 'Onion', 'Yogurt']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans', 'Milk', 'Nutmeg']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Onion', 'Milk']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Onion', 'Nutmeg']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Eggs', 'Milk', 'Onion', 'Nutmeg']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Milk', 'Kidney Beans', 'Onion', 'Nutmeg']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans', 'Milk', 'Nutmeg']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Milk', 'Yogurt']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Eggs', 'Yogurt', 'Kidney Beans', 'Nutmeg']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Eggs', 'Yogurt', 'Milk', 'Nutmeg']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Milk', 'Yogurt', 'Kidney Beans', 'Nutmeg']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans', 'Onion', 'Milk']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Milk', 'Yogurt']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Onion', 'Yogurt']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.5555555555555557
# ================
# Rule: [['Eggs', 'Milk', 'Onion', 'Yogurt']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Milk', 'Kidney Beans', 'Onion', 'Yogurt']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans', 'Onion', 'Nutmeg']] -> [['Yogurt']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Yogurt', 'Kidney Beans', 'Nutmeg']] -> [['Onion']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Onion', 'Yogurt']] -> [['Nutmeg']]
# Support: 0.4
# Confidence: 0.6666666666666667
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Yogurt', 'Onion', 'Nutmeg']] -> [['Kidney Beans']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Yogurt', 'Kidney Beans', 'Onion', 'Nutmeg']] -> [['Eggs']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs', 'Milk', 'Onion', 'Nutmeg']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Yogurt', 'Milk', 'Nutmeg']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Milk', 'Onion', 'Yogurt']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Eggs', 'Yogurt', 'Onion', 'Nutmeg']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Milk', 'Yogurt', 'Onion', 'Nutmeg']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Milk', 'Kidney Beans', 'Onion', 'Nutmeg']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Milk', 'Yogurt', 'Kidney Beans', 'Nutmeg']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Milk', 'Kidney Beans', 'Onion', 'Yogurt']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Yogurt', 'Kidney Beans', 'Onion', 'Nutmeg']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Milk', 'Yogurt', 'Onion', 'Nutmeg']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# =====================================
# Rule: [['Kidney Beans', 'Corn', 'Eggs', 'Ice cream', 'Onion']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Kidney Beans', 'Corn', 'Yogurt', 'Eggs', 'Ice cream']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Corn', 'Yogurt', 'Eggs', 'Ice cream', 'Onion']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Corn', 'Yogurt', 'Eggs', 'Onion']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# ================
# Rule: [['Kidney Beans', 'Corn', 'Yogurt', 'Ice cream', 'Onion']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Kidney Beans', 'Yogurt', 'Eggs', 'Ice cream', 'Onion']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Kidney Beans', 'Dill', 'Eggs', 'Onion', 'Nutmeg']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Kidney Beans', 'Dill', 'Yogurt', 'Eggs', 'Nutmeg']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Kidney Beans', 'Dill', 'Yogurt', 'Eggs', 'Onion']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Dill', 'Yogurt', 'Eggs', 'Onion', 'Nutmeg']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Dill', 'Yogurt', 'Onion', 'Nutmeg']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Kidney Beans', 'Yogurt', 'Eggs', 'Onion', 'Nutmeg']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# =====================================
# Rule: [['Kidney Beans', 'Eggs', 'Milk', 'Onion', 'Nutmeg']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Kidney Beans', 'Yogurt', 'Eggs', 'Milk', 'Nutmeg']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Kidney Beans', 'Yogurt', 'Eggs', 'Milk', 'Onion']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Kidney Beans', 'Yogurt', 'Eggs', 'Onion', 'Nutmeg']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Yogurt', 'Eggs', 'Milk', 'Onion', 'Nutmeg']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Yogurt', 'Milk', 'Onion', 'Nutmeg']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================

# %%
len(items[0])

# %%
item[2][1]

# %%
len(item[2])

# %%
set_items=[item[2][0][0]]
print([list(x) for x in set_items])
print(len(item[2][0][0]))

# %%
pair = item[0] 
items = [x for x in pair]

# %%
items

# %%
Yitems

# %%
Xitems

# %%
len(Xitems)
