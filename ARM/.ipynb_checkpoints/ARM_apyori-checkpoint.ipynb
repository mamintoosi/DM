# %% [markdown]
# ## M. Amintoosi
# ## کاوش الگوهای پرتکرار
# استخراج قوانین انجمنی
#
# https://pypi.org/project/apyori/
#
# http://www.zaxrosenberg.com/unofficial-apyori-documentation/

# %%
import numpy as np  
import matplotlib.pyplot as plt  
import pandas as pd  
from apyori import apriori

# %%
dataset = [['Milk', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
           ['Dill', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
           ['Milk', 'Apple', 'Kidney Beans', 'Eggs'],
           ['Milk', 'Unicorn', 'Corn', 'Kidney Beans', 'Yogurt'],
           ['Corn', 'Onion', 'Kidney Beans', 'Ice cream', 'Eggs', 'Yogurt']]

association_rules = apriori(dataset)#, min_support=0.1, min_confidence=0.4, min_lift=1.2, min_length=2)  
association_results = list(association_rules) 
print(len(association_results))
# Out:
# 171

# %%
minNumX = 1 # antecedent (items_base) and 
minNumY = 1 # consequent (items_add)
# قوانین با تعداد بیشتر از یک قلم در تالی تولید نمی‌شوند!
for item in association_results:
    # تکرار به تعداد قوانین موجود در آیتم
    for i in range(len(item[2])):
        items = [x for x in pair]
        if len(item[2][i][0]) < minNumX:
            continue
        if len(item[2][i][1]) < minNumY:
            continue
        set_items=[item[2][i][0]]
        Xitems = str([list(x) for x in set_items])
        set_items=[item[2][i][1]]
        Yitems = str([list(x) for x in set_items])
        print("Rule: " + Xitems + " -> " + Yitems)

        #second index of the inner list
        print("Support: " + str(item[1]))

        #third index of the list located at 0th
        #of the third index of the inner list

        print("Confidence: " + str(item[2][i][2]))
        print("Lift: " + str(item[2][i][3]))
        print("================")
    print("=====================================")
# Out:
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# =====================================
# Rule: [['Apple']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs']] -> [['Apple']]
# Support: 0.2
# Confidence: 0.25
# Lift: 1.25
# ================
# =====================================
# Rule: [['Apple']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans']] -> [['Apple']]
# Support: 0.2
# Confidence: 0.2
# Lift: 1.0
# ================
# =====================================
# Rule: [['Apple']] -> [['Milk']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Milk']] -> [['Apple']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# =====================================
# Rule: [['Corn']] -> [['Eggs']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.625
# ================
# Rule: [['Eggs']] -> [['Corn']]
# Support: 0.2
# Confidence: 0.25
# Lift: 0.625
# ================
# =====================================
# Rule: [['Corn']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# Rule: [['Ice cream']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Corn']] -> [['Kidney Beans']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans']] -> [['Corn']]
# Support: 0.4
# Confidence: 0.4
# Lift: 1.0
# ================
# =====================================
# Rule: [['Corn']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Milk']] -> [['Corn']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.8333333333333334
# ================
# =====================================
# Rule: [['Corn']] -> [['Onion']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Onion']] -> [['Corn']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.8333333333333334
# ================
# =====================================
# Rule: [['Corn']] -> [['Unicorn']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# Rule: [['Unicorn']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Corn']] -> [['Yogurt']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt']] -> [['Corn']]
# Support: 0.4
# Confidence: 0.5
# Lift: 1.25
# ================
# =====================================
# Rule: [['Dill']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.25
# Lift: 1.25
# ================
# =====================================
# Rule: [['Dill']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.2
# Lift: 1.0
# ================
# =====================================
# Rule: [['Dill']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Nutmeg']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# =====================================
# Rule: [['Dill']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Onion']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# =====================================
# Rule: [['Dill']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.25
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 0.25
# Lift: 1.25
# ================
# Rule: [['Ice cream']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs']] -> [['Kidney Beans']]
# Support: 0.8
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans']] -> [['Eggs']]
# Support: 0.8
# Confidence: 0.8
# Lift: 1.0
# ================
# =====================================
# Rule: [['Eggs']] -> [['Milk']]
# Support: 0.4
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Milk']] -> [['Eggs']]
# Support: 0.4
# Confidence: 0.6666666666666667
# Lift: 0.8333333333333334
# ================
# =====================================
# Rule: [['Eggs']] -> [['Nutmeg']]
# Support: 0.4
# Confidence: 0.5
# Lift: 1.25
# ================
# Rule: [['Nutmeg']] -> [['Eggs']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs']] -> [['Onion']]
# Support: 0.6
# Confidence: 0.7499999999999999
# Lift: 1.2499999999999998
# ================
# Rule: [['Onion']] -> [['Eggs']]
# Support: 0.6
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs']] -> [['Yogurt']]
# Support: 0.6
# Confidence: 0.7499999999999999
# Lift: 0.9374999999999998
# ================
# Rule: [['Yogurt']] -> [['Eggs']]
# Support: 0.6
# Confidence: 0.7499999999999999
# Lift: 0.9374999999999998
# ================
# =====================================
# Rule: [['Ice cream']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 0.2
# Lift: 1.0
# ================
# =====================================
# Rule: [['Ice cream']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Onion']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# =====================================
# Rule: [['Ice cream']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 0.25
# Lift: 1.25
# ================
# =====================================
# Rule: [['Kidney Beans']] -> [['Milk']]
# Support: 0.6
# Confidence: 0.6
# Lift: 1.0
# ================
# Rule: [['Milk']] -> [['Kidney Beans']]
# Support: 0.6
# Confidence: 1.0
# Lift: 1.0
# ================
# =====================================
# Rule: [['Kidney Beans']] -> [['Nutmeg']]
# Support: 0.4
# Confidence: 0.4
# Lift: 1.0
# ================
# Rule: [['Nutmeg']] -> [['Kidney Beans']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.0
# ================
# =====================================
# Rule: [['Kidney Beans']] -> [['Onion']]
# Support: 0.6
# Confidence: 0.6
# Lift: 1.0
# ================
# Rule: [['Onion']] -> [['Kidney Beans']]
# Support: 0.6
# Confidence: 1.0
# Lift: 1.0
# ================
# =====================================
# Rule: [['Kidney Beans']] -> [['Unicorn']]
# Support: 0.2
# Confidence: 0.2
# Lift: 1.0
# ================
# Rule: [['Unicorn']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# =====================================
# Rule: [['Kidney Beans']] -> [['Yogurt']]
# Support: 0.8
# Confidence: 0.8
# Lift: 1.0
# ================
# Rule: [['Yogurt']] -> [['Kidney Beans']]
# Support: 0.8
# Confidence: 1.0
# Lift: 1.0
# ================
# =====================================
# Rule: [['Milk']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.8333333333333334
# ================
# Rule: [['Nutmeg']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# =====================================
# Rule: [['Milk']] -> [['Onion']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.5555555555555557
# ================
# Rule: [['Onion']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.5555555555555557
# ================
# =====================================
# Rule: [['Milk']] -> [['Unicorn']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# Rule: [['Unicorn']] -> [['Milk']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# =====================================
# Rule: [['Milk']] -> [['Yogurt']]
# Support: 0.4
# Confidence: 0.6666666666666667
# Lift: 0.8333333333333334
# ================
# Rule: [['Yogurt']] -> [['Milk']]
# Support: 0.4
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# =====================================
# Rule: [['Nutmeg']] -> [['Onion']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Onion']] -> [['Nutmeg']]
# Support: 0.4
# Confidence: 0.6666666666666667
# Lift: 1.6666666666666667
# ================
# =====================================
# Rule: [['Nutmeg']] -> [['Yogurt']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt']] -> [['Nutmeg']]
# Support: 0.4
# Confidence: 0.5
# Lift: 1.25
# ================
# =====================================
# Rule: [['Onion']] -> [['Yogurt']]
# Support: 0.6
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt']] -> [['Onion']]
# Support: 0.6
# Confidence: 0.7499999999999999
# Lift: 1.2499999999999998
# ================
# =====================================
# Rule: [['Unicorn']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt']] -> [['Unicorn']]
# Support: 0.2
# Confidence: 0.25
# Lift: 1.25
# ================
# =====================================
# Rule: [['Apple', 'Eggs']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Apple', 'Kidney Beans']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Kidney Beans']] -> [['Apple']]
# Support: 0.2
# Confidence: 0.25
# Lift: 1.25
# ================
# =====================================
# Rule: [['Apple', 'Eggs']] -> [['Milk']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Apple', 'Milk']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Milk', 'Eggs']] -> [['Apple']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# =====================================
# Rule: [['Apple', 'Kidney Beans']] -> [['Milk']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Apple', 'Milk']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Milk', 'Kidney Beans']] -> [['Apple']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# =====================================
# Rule: [['Eggs', 'Corn']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# ================
# Rule: [['Corn', 'Ice cream']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Ice cream']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Eggs', 'Corn']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Corn', 'Kidney Beans']] -> [['Eggs']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.625
# ================
# Rule: [['Eggs', 'Kidney Beans']] -> [['Corn']]
# Support: 0.2
# Confidence: 0.25
# Lift: 0.625
# ================
# =====================================
# Rule: [['Eggs', 'Corn']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Corn', 'Onion']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Onion']] -> [['Corn']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.8333333333333334
# ================
# =====================================
# Rule: [['Eggs', 'Corn']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Corn']] -> [['Eggs']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.625
# ================
# Rule: [['Yogurt', 'Eggs']] -> [['Corn']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.8333333333333334
# ================
# =====================================
# Rule: [['Corn', 'Ice cream']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Corn', 'Kidney Beans']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# Rule: [['Kidney Beans', 'Ice cream']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Corn', 'Ice cream']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Corn', 'Onion']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# ================
# Rule: [['Ice cream', 'Onion']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Corn', 'Ice cream']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Corn']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# Rule: [['Yogurt', 'Ice cream']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Corn', 'Kidney Beans']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Milk', 'Corn']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Milk', 'Kidney Beans']] -> [['Corn']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.8333333333333334
# ================
# =====================================
# Rule: [['Corn', 'Kidney Beans']] -> [['Onion']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Corn', 'Onion']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Onion']] -> [['Corn']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.8333333333333334
# ================
# =====================================
# Rule: [['Corn', 'Kidney Beans']] -> [['Unicorn']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# Rule: [['Unicorn', 'Corn']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Unicorn', 'Kidney Beans']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Corn', 'Kidney Beans']] -> [['Yogurt']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Corn']] -> [['Kidney Beans']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Yogurt', 'Kidney Beans']] -> [['Corn']]
# Support: 0.4
# Confidence: 0.5
# Lift: 1.25
# ================
# =====================================
# Rule: [['Milk', 'Corn']] -> [['Unicorn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# ================
# Rule: [['Unicorn', 'Corn']] -> [['Milk']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Milk', 'Unicorn']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Milk', 'Corn']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Corn']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Yogurt', 'Milk']] -> [['Corn']]
# Support: 0.2
# Confidence: 0.5
# Lift: 1.25
# ================
# =====================================
# Rule: [['Corn', 'Onion']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Corn']] -> [['Onion']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Yogurt', 'Onion']] -> [['Corn']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.8333333333333334
# ================
# =====================================
# Rule: [['Unicorn', 'Corn']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Corn']] -> [['Unicorn']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# Rule: [['Yogurt', 'Unicorn']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Eggs', 'Dill']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Dill']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Kidney Beans']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.25
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs', 'Dill']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Nutmeg', 'Dill']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Nutmeg', 'Eggs']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# =====================================
# Rule: [['Eggs', 'Dill']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Onion', 'Dill']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Onion']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# =====================================
# Rule: [['Eggs', 'Dill']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Dill']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Eggs']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# =====================================
# Rule: [['Kidney Beans', 'Dill']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Nutmeg', 'Dill']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Nutmeg', 'Kidney Beans']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# =====================================
# Rule: [['Kidney Beans', 'Dill']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Onion', 'Dill']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Onion']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# =====================================
# Rule: [['Kidney Beans', 'Dill']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Dill']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Yogurt', 'Kidney Beans']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.25
# Lift: 1.25
# ================
# =====================================
# Rule: [['Nutmeg', 'Dill']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Onion', 'Dill']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Nutmeg', 'Onion']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# =====================================
# Rule: [['Nutmeg', 'Dill']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Dill']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Yogurt', 'Nutmeg']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# =====================================
# Rule: [['Onion', 'Dill']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Dill']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Yogurt', 'Onion']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# =====================================
# Rule: [['Eggs', 'Ice cream']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Eggs', 'Kidney Beans']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 0.25
# Lift: 1.25
# ================
# Rule: [['Kidney Beans', 'Ice cream']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs', 'Ice cream']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Onion']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# Rule: [['Ice cream', 'Onion']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs', 'Ice cream']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Eggs']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# Rule: [['Yogurt', 'Ice cream']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans']] -> [['Milk']]
# Support: 0.4
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Milk', 'Eggs']] -> [['Kidney Beans']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Milk', 'Kidney Beans']] -> [['Eggs']]
# Support: 0.4
# Confidence: 0.6666666666666667
# Lift: 0.8333333333333334
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans']] -> [['Nutmeg']]
# Support: 0.4
# Confidence: 0.5
# Lift: 1.25
# ================
# Rule: [['Nutmeg', 'Eggs']] -> [['Kidney Beans']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Nutmeg', 'Kidney Beans']] -> [['Eggs']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans']] -> [['Onion']]
# Support: 0.6
# Confidence: 0.7499999999999999
# Lift: 1.2499999999999998
# ================
# Rule: [['Eggs', 'Onion']] -> [['Kidney Beans']]
# Support: 0.6
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Onion']] -> [['Eggs']]
# Support: 0.6
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans']] -> [['Yogurt']]
# Support: 0.6
# Confidence: 0.7499999999999999
# Lift: 0.9374999999999998
# ================
# Rule: [['Yogurt', 'Eggs']] -> [['Kidney Beans']]
# Support: 0.6
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Yogurt', 'Kidney Beans']] -> [['Eggs']]
# Support: 0.6
# Confidence: 0.7499999999999999
# Lift: 0.9374999999999998
# ================
# =====================================
# Rule: [['Milk', 'Eggs']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 0.5
# Lift: 1.25
# ================
# Rule: [['Nutmeg', 'Eggs']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Nutmeg', 'Milk']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Milk', 'Eggs']] -> [['Onion']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Eggs', 'Onion']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.5555555555555557
# ================
# Rule: [['Milk', 'Onion']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Milk', 'Eggs']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.625
# ================
# Rule: [['Yogurt', 'Eggs']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.5555555555555557
# ================
# Rule: [['Yogurt', 'Milk']] -> [['Eggs']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.625
# ================
# =====================================
# Rule: [['Nutmeg', 'Eggs']] -> [['Onion']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Onion']] -> [['Nutmeg']]
# Support: 0.4
# Confidence: 0.6666666666666667
# Lift: 1.6666666666666667
# ================
# Rule: [['Nutmeg', 'Onion']] -> [['Eggs']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Nutmeg', 'Eggs']] -> [['Yogurt']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Eggs']] -> [['Nutmeg']]
# Support: 0.4
# Confidence: 0.6666666666666667
# Lift: 1.6666666666666667
# ================
# Rule: [['Yogurt', 'Nutmeg']] -> [['Eggs']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs', 'Onion']] -> [['Yogurt']]
# Support: 0.6
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Eggs']] -> [['Onion']]
# Support: 0.6
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Yogurt', 'Onion']] -> [['Eggs']]
# Support: 0.6
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Kidney Beans', 'Ice cream']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Ice cream', 'Onion']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Kidney Beans', 'Onion']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# =====================================
# Rule: [['Kidney Beans', 'Ice cream']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Ice cream']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Yogurt', 'Kidney Beans']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 0.25
# Lift: 1.25
# ================
# =====================================
# Rule: [['Ice cream', 'Onion']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Ice cream']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Yogurt', 'Onion']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# =====================================
# Rule: [['Milk', 'Kidney Beans']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.8333333333333334
# ================
# Rule: [['Nutmeg', 'Kidney Beans']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Nutmeg', 'Milk']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# =====================================
# Rule: [['Milk', 'Kidney Beans']] -> [['Onion']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.5555555555555557
# ================
# Rule: [['Kidney Beans', 'Onion']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.5555555555555557
# ================
# Rule: [['Milk', 'Onion']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# =====================================
# Rule: [['Milk', 'Kidney Beans']] -> [['Unicorn']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# Rule: [['Unicorn', 'Kidney Beans']] -> [['Milk']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Milk', 'Unicorn']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# =====================================
# Rule: [['Milk', 'Kidney Beans']] -> [['Yogurt']]
# Support: 0.4
# Confidence: 0.6666666666666667
# Lift: 0.8333333333333334
# ================
# Rule: [['Yogurt', 'Kidney Beans']] -> [['Milk']]
# Support: 0.4
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Yogurt', 'Milk']] -> [['Kidney Beans']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.0
# ================
# =====================================
# Rule: [['Nutmeg', 'Kidney Beans']] -> [['Onion']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Kidney Beans', 'Onion']] -> [['Nutmeg']]
# Support: 0.4
# Confidence: 0.6666666666666667
# Lift: 1.6666666666666667
# ================
# Rule: [['Nutmeg', 'Onion']] -> [['Kidney Beans']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.0
# ================
# =====================================
# Rule: [['Nutmeg', 'Kidney Beans']] -> [['Yogurt']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Kidney Beans']] -> [['Nutmeg']]
# Support: 0.4
# Confidence: 0.5
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Nutmeg']] -> [['Kidney Beans']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.0
# ================
# =====================================
# Rule: [['Kidney Beans', 'Onion']] -> [['Yogurt']]
# Support: 0.6
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Kidney Beans']] -> [['Onion']]
# Support: 0.6
# Confidence: 0.7499999999999999
# Lift: 1.2499999999999998
# ================
# Rule: [['Yogurt', 'Onion']] -> [['Kidney Beans']]
# Support: 0.6
# Confidence: 1.0
# Lift: 1.0
# ================
# =====================================
# Rule: [['Unicorn', 'Kidney Beans']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Kidney Beans']] -> [['Unicorn']]
# Support: 0.2
# Confidence: 0.25
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Unicorn']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# =====================================
# Rule: [['Nutmeg', 'Milk']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Milk', 'Onion']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Nutmeg', 'Onion']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# =====================================
# Rule: [['Nutmeg', 'Milk']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Milk']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 0.5
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Nutmeg']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# =====================================
# Rule: [['Milk', 'Onion']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Milk']] -> [['Onion']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Yogurt', 'Onion']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.5555555555555557
# ================
# =====================================
# Rule: [['Milk', 'Unicorn']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Milk']] -> [['Unicorn']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# Rule: [['Yogurt', 'Unicorn']] -> [['Milk']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# =====================================
# Rule: [['Nutmeg', 'Onion']] -> [['Yogurt']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Nutmeg']] -> [['Onion']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Yogurt', 'Onion']] -> [['Nutmeg']]
# Support: 0.4
# Confidence: 0.6666666666666667
# Lift: 1.6666666666666667
# ================
# =====================================
# Rule: [['Apple', 'Eggs', 'Kidney Beans']] -> [['Milk']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Milk', 'Apple', 'Eggs']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Apple', 'Milk', 'Kidney Beans']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Milk', 'Eggs', 'Kidney Beans']] -> [['Apple']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# =====================================
# Rule: [['Eggs', 'Corn', 'Ice cream']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Eggs', 'Corn', 'Kidney Beans']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# ================
# Rule: [['Kidney Beans', 'Corn', 'Ice cream']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Kidney Beans', 'Eggs', 'Ice cream']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Eggs', 'Corn', 'Ice cream']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Corn', 'Onion']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# ================
# Rule: [['Corn', 'Ice cream', 'Onion']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Ice cream', 'Onion']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Eggs', 'Corn', 'Ice cream']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Yogurt', 'Corn']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# ================
# Rule: [['Yogurt', 'Corn', 'Ice cream']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Eggs', 'Ice cream']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Eggs', 'Corn', 'Kidney Beans']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Corn', 'Onion']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Corn', 'Kidney Beans', 'Onion']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Onion']] -> [['Corn']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.8333333333333334
# ================
# =====================================
# Rule: [['Eggs', 'Corn', 'Kidney Beans']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Yogurt', 'Corn']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Yogurt', 'Corn', 'Kidney Beans']] -> [['Eggs']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.625
# ================
# Rule: [['Yogurt', 'Eggs', 'Kidney Beans']] -> [['Corn']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.8333333333333334
# ================
# =====================================
# Rule: [['Eggs', 'Corn', 'Onion']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Yogurt', 'Corn']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Yogurt', 'Corn', 'Onion']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Eggs', 'Onion']] -> [['Corn']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.8333333333333334
# ================
# =====================================
# Rule: [['Kidney Beans', 'Corn', 'Ice cream']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Corn', 'Ice cream', 'Onion']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Corn', 'Kidney Beans', 'Onion']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# ================
# Rule: [['Kidney Beans', 'Ice cream', 'Onion']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Kidney Beans', 'Corn', 'Ice cream']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Corn', 'Ice cream']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Yogurt', 'Corn', 'Kidney Beans']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# Rule: [['Kidney Beans', 'Yogurt', 'Ice cream']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Corn', 'Ice cream', 'Onion']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Corn', 'Ice cream']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Yogurt', 'Corn', 'Onion']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# ================
# Rule: [['Yogurt', 'Ice cream', 'Onion']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Milk', 'Corn', 'Kidney Beans']] -> [['Unicorn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# ================
# Rule: [['Unicorn', 'Corn', 'Kidney Beans']] -> [['Milk']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Unicorn', 'Milk', 'Corn']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Milk', 'Unicorn', 'Kidney Beans']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Milk', 'Corn', 'Kidney Beans']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Corn', 'Kidney Beans']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Yogurt', 'Milk', 'Corn']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Yogurt', 'Milk', 'Kidney Beans']] -> [['Corn']]
# Support: 0.2
# Confidence: 0.5
# Lift: 1.25
# ================
# =====================================
# Rule: [['Corn', 'Kidney Beans', 'Onion']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Corn', 'Kidney Beans']] -> [['Onion']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Yogurt', 'Corn', 'Onion']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Yogurt', 'Kidney Beans', 'Onion']] -> [['Corn']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.8333333333333334
# ================
# =====================================
# Rule: [['Unicorn', 'Corn', 'Kidney Beans']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Corn', 'Kidney Beans']] -> [['Unicorn']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# Rule: [['Unicorn', 'Yogurt', 'Corn']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Yogurt', 'Unicorn', 'Kidney Beans']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Unicorn', 'Milk', 'Corn']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Milk', 'Corn']] -> [['Unicorn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# ================
# Rule: [['Unicorn', 'Yogurt', 'Corn']] -> [['Milk']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Yogurt', 'Milk', 'Unicorn']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans', 'Dill']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Nutmeg', 'Eggs', 'Dill']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Nutmeg', 'Kidney Beans', 'Dill']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Nutmeg', 'Eggs', 'Kidney Beans']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans', 'Dill']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Onion', 'Dill']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Onion', 'Kidney Beans', 'Dill']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Onion']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans', 'Dill']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Eggs', 'Dill']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Yogurt', 'Kidney Beans', 'Dill']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Eggs', 'Kidney Beans']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# =====================================
# Rule: [['Nutmeg', 'Eggs', 'Dill']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Onion', 'Dill']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Nutmeg', 'Onion', 'Dill']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Nutmeg', 'Eggs', 'Onion']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# =====================================
# Rule: [['Nutmeg', 'Eggs', 'Dill']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Eggs', 'Dill']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Dill']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Eggs']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# =====================================
# Rule: [['Eggs', 'Onion', 'Dill']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Eggs', 'Dill']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Yogurt', 'Onion', 'Dill']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Eggs', 'Onion']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# =====================================
# Rule: [['Nutmeg', 'Kidney Beans', 'Dill']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Onion', 'Kidney Beans', 'Dill']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Nutmeg', 'Onion', 'Dill']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Nutmeg', 'Kidney Beans', 'Onion']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# =====================================
# Rule: [['Nutmeg', 'Kidney Beans', 'Dill']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Kidney Beans', 'Dill']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Dill']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Kidney Beans']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# =====================================
# Rule: [['Onion', 'Kidney Beans', 'Dill']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Kidney Beans', 'Dill']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Yogurt', 'Onion', 'Dill']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Yogurt', 'Kidney Beans', 'Onion']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# =====================================
# Rule: [['Nutmeg', 'Onion', 'Dill']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Dill']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Yogurt', 'Onion', 'Dill']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Onion']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# =====================================
# Rule: [['Kidney Beans', 'Eggs', 'Ice cream']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Ice cream', 'Onion']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Onion']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# Rule: [['Kidney Beans', 'Ice cream', 'Onion']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Kidney Beans', 'Eggs', 'Ice cream']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Eggs', 'Ice cream']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Yogurt', 'Eggs', 'Kidney Beans']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# Rule: [['Kidney Beans', 'Yogurt', 'Ice cream']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs', 'Ice cream', 'Onion']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Eggs', 'Ice cream']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Yogurt', 'Eggs', 'Onion']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# Rule: [['Yogurt', 'Ice cream', 'Onion']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Milk', 'Eggs', 'Kidney Beans']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 0.5
# Lift: 1.25
# ================
# Rule: [['Nutmeg', 'Eggs', 'Kidney Beans']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Nutmeg', 'Milk', 'Eggs']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Nutmeg', 'Milk', 'Kidney Beans']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Milk', 'Eggs', 'Kidney Beans']] -> [['Onion']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Onion']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.5555555555555557
# ================
# Rule: [['Milk', 'Eggs', 'Onion']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Milk', 'Kidney Beans', 'Onion']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Milk', 'Eggs', 'Kidney Beans']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.625
# ================
# Rule: [['Yogurt', 'Eggs', 'Kidney Beans']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.5555555555555557
# ================
# Rule: [['Yogurt', 'Milk', 'Eggs']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Yogurt', 'Milk', 'Kidney Beans']] -> [['Eggs']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.625
# ================
# =====================================
# Rule: [['Nutmeg', 'Eggs', 'Kidney Beans']] -> [['Onion']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Kidney Beans', 'Onion']] -> [['Nutmeg']]
# Support: 0.4
# Confidence: 0.6666666666666667
# Lift: 1.6666666666666667
# ================
# Rule: [['Nutmeg', 'Eggs', 'Onion']] -> [['Kidney Beans']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Nutmeg', 'Kidney Beans', 'Onion']] -> [['Eggs']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Nutmeg', 'Eggs', 'Kidney Beans']] -> [['Yogurt']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Eggs', 'Kidney Beans']] -> [['Nutmeg']]
# Support: 0.4
# Confidence: 0.6666666666666667
# Lift: 1.6666666666666667
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Eggs']] -> [['Kidney Beans']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Kidney Beans']] -> [['Eggs']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans', 'Onion']] -> [['Yogurt']]
# Support: 0.6
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Eggs', 'Kidney Beans']] -> [['Onion']]
# Support: 0.6
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Yogurt', 'Eggs', 'Onion']] -> [['Kidney Beans']]
# Support: 0.6
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Yogurt', 'Kidney Beans', 'Onion']] -> [['Eggs']]
# Support: 0.6
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Nutmeg', 'Milk', 'Eggs']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Milk', 'Eggs', 'Onion']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# ...
# ================
# Rule: [['Yogurt', 'Milk', 'Unicorn']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# =====================================
# Rule: [['Nutmeg', 'Kidney Beans', 'Onion']] -> [['Yogurt']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Kidney Beans']] -> [['Onion']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Yogurt', 'Kidney Beans', 'Onion']] -> [['Nutmeg']]
# Support: 0.4
# Confidence: 0.6666666666666667
# Lift: 1.6666666666666667
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Onion']] -> [['Kidney Beans']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.0
# ================
# =====================================
# Rule: [['Nutmeg', 'Milk', 'Onion']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Milk']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Yogurt', 'Milk', 'Onion']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Onion']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans', 'Corn', 'Ice cream']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Corn', 'Ice cream', 'Onion']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Eggs', 'Corn', 'Kidney Beans', 'Onion']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# ================
# Rule: [['Kidney Beans', 'Corn', 'Ice cream', 'Onion']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Kidney Beans', 'Eggs', 'Ice cream', 'Onion']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Eggs', 'Kidney Beans', 'Corn', 'Ice cream']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Yogurt', 'Corn', 'Ice cream']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Eggs', 'Yogurt', 'Corn', 'Kidney Beans']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# ================
# Rule: [['Kidney Beans', 'Yogurt', 'Corn', 'Ice cream']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Kidney Beans', 'Yogurt', 'Eggs', 'Ice cream']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Eggs', 'Corn', 'Ice cream', 'Onion']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Yogurt', 'Corn', 'Ice cream']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Yogurt', 'Corn', 'Onion']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# ================
# Rule: [['Yogurt', 'Corn', 'Ice cream', 'Onion']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Eggs', 'Ice cream', 'Onion']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Eggs', 'Corn', 'Kidney Beans', 'Onion']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Eggs', 'Yogurt', 'Corn', 'Kidney Beans']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Eggs', 'Yogurt', 'Corn', 'Onion']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Yogurt', 'Corn', 'Kidney Beans', 'Onion']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Eggs', 'Kidney Beans', 'Onion']] -> [['Corn']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.8333333333333334
# ================
# =====================================
# Rule: [['Kidney Beans', 'Corn', 'Ice cream', 'Onion']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Kidney Beans', 'Yogurt', 'Corn', 'Ice cream']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Yogurt', 'Corn', 'Ice cream', 'Onion']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Yogurt', 'Corn', 'Kidney Beans', 'Onion']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# ================
# Rule: [['Kidney Beans', 'Yogurt', 'Ice cream', 'Onion']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Unicorn', 'Milk', 'Corn', 'Kidney Beans']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Milk', 'Corn', 'Kidney Beans']] -> [['Unicorn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# ================
# Rule: [['Unicorn', 'Yogurt', 'Corn', 'Kidney Beans']] -> [['Milk']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Unicorn', 'Yogurt', 'Milk', 'Corn']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Yogurt', 'Milk', 'Unicorn', 'Kidney Beans']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Nutmeg', 'Eggs', 'Kidney Beans', 'Dill']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Onion', 'Eggs', 'Kidney Beans', 'Dill']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Nutmeg', 'Eggs', 'Onion', 'Dill']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Nutmeg', 'Onion', 'Kidney Beans', 'Dill']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Nutmeg', 'Eggs', 'Kidney Beans', 'Onion']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# =====================================
# Rule: [['Nutmeg', 'Eggs', 'Kidney Beans', 'Dill']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Eggs', 'Kidney Beans', 'Dill']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Eggs', 'Dill']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Kidney Beans', 'Dill']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Eggs', 'Kidney Beans']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# =====================================
# Rule: [['Onion', 'Eggs', 'Kidney Beans', 'Dill']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Eggs', 'Kidney Beans', 'Dill']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Yogurt', 'Eggs', 'Onion', 'Dill']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Yogurt', 'Onion', 'Kidney Beans', 'Dill']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Eggs', 'Kidney Beans', 'Onion']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# =====================================
# Rule: [['Nutmeg', 'Eggs', 'Onion', 'Dill']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Eggs', 'Dill']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Yogurt', 'Eggs', 'Onion', 'Dill']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Onion', 'Dill']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Eggs', 'Onion']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# =====================================
# Rule: [['Nutmeg', 'Onion', 'Kidney Beans', 'Dill']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Kidney Beans', 'Dill']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Yogurt', 'Onion', 'Kidney Beans', 'Dill']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Onion', 'Dill']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Kidney Beans', 'Onion']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# =====================================
# Rule: [['Kidney Beans', 'Eggs', 'Ice cream', 'Onion']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Kidney Beans', 'Yogurt', 'Eggs', 'Ice cream']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Yogurt', 'Eggs', 'Ice cream', 'Onion']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Yogurt', 'Eggs', 'Kidney Beans', 'Onion']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 1.6666666666666667
# ================
# Rule: [['Kidney Beans', 'Yogurt', 'Ice cream', 'Onion']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Nutmeg', 'Milk', 'Eggs', 'Kidney Beans']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Milk', 'Eggs', 'Kidney Beans', 'Onion']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Nutmeg', 'Eggs', 'Kidney Beans', 'Onion']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Nutmeg', 'Milk', 'Eggs', 'Onion']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Nutmeg', 'Milk', 'Kidney Beans', 'Onion']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Nutmeg', 'Milk', 'Eggs', 'Kidney Beans']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Milk', 'Eggs', 'Kidney Beans']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Eggs', 'Kidney Beans']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Milk', 'Eggs']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Milk', 'Kidney Beans']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Milk', 'Eggs', 'Kidney Beans', 'Onion']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Milk', 'Eggs', 'Kidney Beans']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Yogurt', 'Eggs', 'Kidney Beans', 'Onion']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.33333333333333337
# Lift: 0.5555555555555557
# ================
# Rule: [['Yogurt', 'Milk', 'Eggs', 'Onion']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Yogurt', 'Milk', 'Kidney Beans', 'Onion']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Nutmeg', 'Eggs', 'Kidney Beans', 'Onion']] -> [['Yogurt']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Eggs', 'Kidney Beans']] -> [['Onion']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Yogurt', 'Eggs', 'Kidney Beans', 'Onion']] -> [['Nutmeg']]
# Support: 0.4
# Confidence: 0.6666666666666667
# Lift: 1.6666666666666667
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Eggs', 'Onion']] -> [['Kidney Beans']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Kidney Beans', 'Onion']] -> [['Eggs']]
# Support: 0.4
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Nutmeg', 'Milk', 'Eggs', 'Onion']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Milk', 'Eggs']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Yogurt', 'Milk', 'Eggs', 'Onion']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Eggs', 'Onion']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Milk', 'Onion']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================
# Rule: [['Nutmeg', 'Milk', 'Kidney Beans', 'Onion']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Milk', 'Kidney Beans']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Yogurt', 'Milk', 'Kidney Beans', 'Onion']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Kidney Beans', 'Onion']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Milk', 'Onion']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# =====================================
# Rule: [['Onion', 'Eggs', 'Kidney Beans', 'Corn', 'Ice cream']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Eggs', 'Kidney Beans', 'Corn', 'Ice cream']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Yogurt', 'Onion', 'Eggs', 'Corn', 'Ice cream']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Yogurt', 'Onion', 'Eggs', 'Corn', 'Kidney Beans']] -> [['Ice cream']]
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# ================
# Rule: [['Yogurt', 'Onion', 'Corn', 'Kidney Beans', 'Ice cream']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Onion', 'Eggs', 'Kidney Beans', 'Ice cream']] -> [['Corn']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# =====================================
# Rule: [['Nutmeg', 'Onion', 'Eggs', 'Kidney Beans', 'Dill']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Eggs', 'Kidney Beans', 'Dill']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Yogurt', 'Onion', 'Eggs', 'Kidney Beans', 'Dill']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Onion', 'Eggs', 'Dill']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Onion', 'Kidney Beans', 'Dill']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Onion', 'Eggs', 'Kidney Beans']] -> [['Dill']]
# Support: 0.2
# Confidence: 0.5
# Lift: 2.5
# ================
# =====================================
# Rule: [['Nutmeg', 'Milk', 'Onion', 'Eggs', 'Kidney Beans']] -> [['Yogurt']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Milk', 'Eggs', 'Kidney Beans']] -> [['Onion']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.6666666666666667
# ================
# Rule: [['Yogurt', 'Milk', 'Onion', 'Eggs', 'Kidney Beans']] -> [['Nutmeg']]
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Onion', 'Eggs', 'Kidney Beans']] -> [['Milk']]
# Support: 0.2
# Confidence: 0.5
# Lift: 0.8333333333333334
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Milk', 'Onion', 'Eggs']] -> [['Kidney Beans']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.0
# ================
# Rule: [['Yogurt', 'Nutmeg', 'Milk', 'Onion', 'Kidney Beans']] -> [['Eggs']]
# Support: 0.2
# Confidence: 1.0
# Lift: 1.25
# ================
# =====================================

# %%
len(items[0])
# Out:
# 6

# %%
item[2][1]
# Out:
# OrderedStatistic(items_base=frozenset({'Yogurt', 'Nutmeg', 'Milk', 'Eggs', 'Kidney Beans'}), items_add=frozenset({'Onion'}), confidence=1.0, lift=1.6666666666666667)

# %%
len(item[2])
# Out:
# 4

# %%
set_items=[item[2][0][0]]
print([list(x) for x in set_items])
print(len(item[2][0][0]))
# Out:
# [['Nutmeg', 'Milk', 'Onion', 'Eggs', 'Kidney Beans']]
# 5

# %%
pair = item[0] 
items = [x for x in pair]

# %%
items
# Out:
# ['Yogurt', 'Nutmeg', 'Milk', 'Onion', 'Eggs', 'Kidney Beans']

# %%
Yitems
# Out:
# "[['Eggs']]"

# %%
Xitems
# Out:
# "[['Yogurt', 'Nutmeg', 'Milk', 'Onion', 'Kidney Beans']]"

# %%
len(Xitems)
# Out:
# 55
